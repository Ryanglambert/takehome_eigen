# %%
import pandas as pd

# %%
with open('example.csv', 'r') as f:
    thing = f.readlines()

# %%
df = pd.read_csv('example.csv', header=None, sep=' ', delimiter=',')

# %%
df
# Out:
#              0                                                  1  \
# 0       people  doc6.txt doc5.txt doc4.txt doc1.txt doc3.txt d...
# 1         iraq                doc5.txt doc1.txt doc3.txt doc2.txt
# 2      country       doc5.txt doc4.txt doc1.txt doc3.txt doc2.txt
# 3         time  doc6.txt doc5.txt doc4.txt doc1.txt doc3.txt d...
# 4           ve  doc6.txt doc5.txt doc4.txt doc1.txt doc3.txt d...
# 5      america       doc5.txt doc4.txt doc1.txt doc3.txt doc2.txt
# 6         know  doc6.txt doc5.txt doc4.txt doc1.txt doc3.txt d...
# 7          let       doc6.txt doc5.txt doc1.txt doc3.txt doc2.txt
# 8     american  doc6.txt doc5.txt doc4.txt doc1.txt doc3.txt d...
# 9   government  doc6.txt doc5.txt doc4.txt doc1.txt doc3.txt d...
# 10        work  doc6.txt doc5.txt doc4.txt doc1.txt doc3.txt d...
# 11        just  doc6.txt doc5.txt doc4.txt doc1.txt doc3.txt d...
# 12         war  doc6.txt doc5.txt doc4.txt doc1.txt doc3.txt d...
# ...
